# %%
import pandas as pd
df=pd.read_csv('bengaluru_house_prices - bengaluru_house_prices.csv')

# %% [markdown]
# # 1. **`UNDERSTANDING THE DATA`**

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK   Coomee       1056   2.0      1.0   39.07
# ...

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0   Coomee       1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.tail()
# Out:
#                   area_type   availability               location       size  \
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony  price
# 13315  ArsiaEx       3453   4.0      0.0  231.0
# 13316      NaN       3600   5.0      NaN  400.0
# 13317  Mahla T       1141   2.0      1.0   60.0
# 13318  SollyCl       4689   4.0      1.0  488.0
# 13319      NaN        550   1.0      1.0   17.0

# %%
df.sample()
# Out:
#                   area_type   availability    location   size  society  \
# 10768  Super built-up  Area  Ready To Move  Ambalipura  2 BHK  SJodsed
#
#       total_sqft  bath  balcony  price
# 10768       1700   2.0      2.0   76.0

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df.describe(include=['object','category'])
# Out:
#                    area_type   availability    location   size  society  \
# count                  13320          13320       13319  13304     7818
# unique                     4             81        1294     31     2688
# top     Super built-up  Area  Ready To Move  Whitefield  2 BHK  GrrvaGr
# freq                    8790          10581         541   5199       80
#
#        total_sqft
# count       13320
# unique       2117
# top          1200
# freq          843

# %%
df.describe(include='all')
# Out:
#                    area_type   availability    location   size  society  \
# count                  13320          13320       13319  13304     7818
# unique                     4             81        1294     31     2688
# top     Super built-up  Area  Ready To Move  Whitefield  2 BHK  GrrvaGr
# freq                    8790          10581         541   5199       80
# mean                     NaN            NaN         NaN    NaN      NaN
# std                      NaN            NaN         NaN    NaN      NaN
# min                      NaN            NaN         NaN    NaN      NaN
# 25%                      NaN            NaN         NaN    NaN      NaN
# 50%                      NaN            NaN         NaN    NaN      NaN
# 75%                      NaN            NaN         NaN    NaN      NaN
# max                      NaN            NaN         NaN    NaN      NaN
#
#        total_sqft          bath       balcony         price
# ...

# %%
df.nunique() # to get unique values
# Out:
# area_type          4
# availability      81
# location        1294
# size              31
# society         2688
# total_sqft      2117
# bath              19
# balcony            4
# price           1994
# dtype: int64

# %%
df['location'].unique()
# Out:
# array(['Electronic City Phase II', 'Chikka Tirupathi', 'Uttarahalli', ...,
#        '12th cross srinivas nagar banshankari 3rd stage',
#        'Havanur extension', 'Abshot Layout'], dtype=object)

# %%
df['balcony'].value_counts()
# Out:
# balcony
# 2.0    5113
# 1.0    4897
# 3.0    1672
# 0.0    1029
# Name: count, dtype: int64

# %% [markdown]
# # 2. **`DATA CLEANING`**

# %%
df1=df.copy()

# %%
df1.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df1.drop(columns=['society'],inplace=True) # dropped the 'society' column cause it have so many null values

# %%
df1.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          1
# size             16
# total_sqft        0
# bath             73
# balcony         609
# price             0
# dtype: int64

# %%
df1['location'].mode()
# Out:
# 0    Whitefield
# Name: location, dtype: object

# %%
df1['location'].fillna(df1['location'].mode()[0],inplace=True)
# Out:
# <ipython-input-121-b8efb4d1ba50>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['location'].fillna(df1['location'].mode()[0],inplace=True)

# %%
df1['size'].fillna(df1['size'].mode()[0],inplace=True)
# Out:
# <ipython-input-122-c57aab48f5ef>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['size'].fillna(df1['size'].mode()[0],inplace=True)

# %%
df1['balcony'].hist()
# Out:
# <Axes: >

# %%
df1['balcony'].fillna(df1['balcony'].mean(),inplace=True)
# Out:
# <ipython-input-124-8a07558b391b>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['balcony'].fillna(df1['balcony'].mean(),inplace=True)

# %%
df1['bath'].hist()
# Out:
# <Axes: >

# %%
df1['bath'].fillna(df1['bath'].median(),inplace=True)
# Out:
# <ipython-input-126-2730037c55a2>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['bath'].fillna(df1['bath'].median(),inplace=True)

# %%
df1.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 569

# %%
df1.drop_duplicates(inplace=True)

# %%
print(df1.shape)
# Out:
# (12751, 8)

# %%
df1['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df1['size']=df1['size'].str.extract(r'(\d+\.?\d*)')

# %%
df1['size'].unique()
# Out:
# array(['2', '4', '3', '6', '1', '8', '7', '5', '11', '9', '27', '10',
#        '19', '16', '43', '14', '12', '13', '18'], dtype=object)

# %%
df1['total_sqft']=df1['total_sqft'].str.extract(r'(\d+\.?\d*)')

# %%
df1['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '2758', '774', '4689'], dtype=object)

# %%
df1['total_sqft'].value_counts()
# Out:
# total_sqft
# 1200       809
# 1100       212
# 1500       205
# 2400       197
# 600        178
#           ...
# 78.03        1
# 1208.51      1
# 804.1        1
# 2435         1
# 4689         1
# Name: count, Length: 1949, dtype: int64

# %%
df1['total_sqft']=df1['total_sqft'].astype('float')

# %%
df1['size']=df1['size'].astype('int')
df1['bath']=df1['bath'].astype('int')
df1['balcony']=df1['balcony'].astype('int')

# %%
df1.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size              int64
# total_sqft      float64
# bath              int64
# balcony           int64
# price           float64
# dtype: object

# %% [markdown]
# # 3. **`DATA VISUALIZATION`**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# set plot style
sns.set_style("whitegrid")

# Distribution plot for numeric columns
fig, axes = plt.subplots(2,2,figsize=(14,10))

# price Distribution
sns.histplot(df1["price"],color="blue",ax=axes[0,0])
axes[0,0].set_title("Price Distribution")

# Total sqft distribution
sns.histplot(df1["total_sqft"],color="k",ax=axes[0,1])
axes[0,1].set_title("Total sqft Distribution")

# Bath distribution
sns.histplot(df1["bath"],color="green",ax=axes[1,0])
axes[1,0].set_title("Bath Distribution")

# Balcony distribution
sns.histplot(df1["balcony"],color="red",ax=axes[1,1])
axes[1,1].set_title("Balcony Distribution")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# set the plot size for all plots
plt.figure(figsize=(16,12))

# Barplot: Average price by area_type
plt.subplot(2,2,1)
sns.barplot(x="area_type",y="price",data=df1,palette="Set2")
plt.title("Average price by area_type")
plt.xlabel("area_type")
plt.ylabel("Average Price")

# Barplot: Average Total Sqft by area_type
plt.subplot(2,2,2)
sns.barplot(x="area_type",y="total_sqft",data=df1,palette="Set2")
plt.title("Average Total Sqft by area_type")
plt.xlabel("area_type")
plt.ylabel("Average Total Sqft")

# Barplot: Average Bath by area_type
plt.subplot(2,2,3)
sns.barplot(x="area_type",y="bath",data=df1,palette="Set2")
plt.title("Average Bath by area_type")
plt.xlabel("area_type")
plt.ylabel("Average Number of Bathrooms")

#Barplot: Average Balcony by area_type
plt.subplot(2,2,4)
sns.barplot(x="area_type",y="balcony",data=df1,palette="Set2")
plt.title("Average Balcony by area_type")
plt.xlabel("area_type")
plt.ylabel("Average Number of Balconies")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-141-df5e9d740ad9>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="area_type",y="price",data=df1,palette="Set2")
# <ipython-input-141-df5e9d740ad9>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="area_type",y="total_sqft",data=df1,palette="Set2")
# <ipython-input-141-df5e9d740ad9>:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="area_type",y="bath",data=df1,palette="Set2")
# <ipython-input-141-df5e9d740ad9>:30: FutureWarning:
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# set plot size for all plots
plt.figure(figsize=(16,12))

# scatter plot: price vs total_sqft
plt.subplot(2,2,1)
sns.scatterplot(x="total_sqft",y="price",data=df1,hue='area_type',palette='coolwarm',alpha=0)
plt.title("Price vs total_sqft")
# Out:
# Text(0.5, 1.0, 'Price vs total_sqft')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# set the plot size for all plots
plt.figure(figsize=(16,10))

#scatterplot : Price vs Total Sqft
plt.subplot(2,2,1)
sns.scatterplot(x="total_sqft",y="price",data=df1,hue="area_type",palette="coolwarm",alpha=0.6)
plt.title("Price vs Total Sqft")
plt.xlabel("Total Sqft")
plt.ylabel("Price")

# Scatter plot:Price vs bath
plt.subplot(2,2,2)
sns.scatterplot(x="bath",y="price",data=df1,hue="area_type",palette="coolwarm",alpha=0.6)
plt.title("Price vs Bath")
plt.xlabel("Number of Bathrooms")
plt.ylabel("Price")

# Scatter plot:Price vs Balcony
plt.subplot(2,2,3)
sns.scatterplot(x="balcony",y="price",data=df1,hue="area_type",palette="coolwarm",alpha=0.6)
plt.title("Price vs Balcony")
plt.xlabel("Number of Balconies")
plt.ylabel("Price")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the plot size for all plots
plt.figure(figsize=(16, 12))

# Create a subplot grid for 4 plots (2 rows, 2 columns)
plt.subplot(2, 2, 1)
sns.boxplot(x='area_type', y='price', data=df1, palette="Set2")
plt.title('Price Distribution by Availability Status')
plt.xlabel('Availability Status')
plt.ylabel('Price')

plt.subplot(2, 2, 2)
sns.boxplot(x='area_type', y='total_sqft', data=df1, palette="Set2")
plt.title('Total Sqft Distribution by Availability Status')
plt.xlabel('Availability Status')
plt.ylabel('Total Sqft')

plt.subplot(2, 2, 3)
sns.boxplot(x='area_type', y='bath', data=df1, palette="Set2")
plt.title('Bath Distribution by Availability Status')
plt.xlabel('Availability Status')
plt.ylabel('Number of Bathrooms')

plt.subplot(2, 2, 4)
sns.boxplot(x='area_type', y='balcony', data=df1, palette="Set2")
plt.title('Balcony Distribution by Availability Status')
plt.xlabel('Availability Status')
plt.ylabel('Number of Balconies')

# Adjust the layout to ensure the plots fit nicely
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-144-05863df9389b>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='area_type', y='price', data=df1, palette="Set2")
# <ipython-input-144-05863df9389b>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='area_type', y='total_sqft', data=df1, palette="Set2")
# <ipython-input-144-05863df9389b>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='area_type', y='bath', data=df1, palette="Set2")
# <ipython-input-144-05863df9389b>:27: FutureWarning:
#
# ...

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='area_type', data=df1, palette="Set1")
plt.title('Count of Properties by Area Type')
plt.xlabel('Area Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# Location is likely to have many unique values, so we can limit the categories shown
plt.figure(figsize=(12, 6))
top_locations = df1['location'].value_counts().nlargest(10)  # Show top 10 locations
sns.countplot(x='location', data=df1[df1['location'].isin(top_locations.index)], palette="Set2")
plt.title('Count of Properties by Location (Top 10)')
plt.xlabel('Location')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-145-98feb93e9e1e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='area_type', data=df1, palette="Set1")
# <ipython-input-145-98feb93e9e1e>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='location', data=df1[df1['location'].isin(top_locations.index)], palette="Set2")

# %%
print(top_locations)
# Out:
# location
# Whitefield               525
# Sarjapur  Road           379
# Electronic City          288
# Kanakpura Road           242
# Thanisandra              232
# Yelahanka                210
# Marathahalli             169
# Hebbal                   161
# Raja Rajeshwari Nagar    159
# Uttarahalli              154
# Name: count, dtype: int64

# %% [markdown]
# # 4. **`OUTLIER DETECTION`**

# %%
df2 = df1.copy()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12751 entries, 0 to 13318
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     12751 non-null  object
#  1   availability  12751 non-null  object
#  2   location      12751 non-null  object
#  3   size          12751 non-null  int64
#  4   total_sqft    12751 non-null  float64
#  5   bath          12751 non-null  int64
#  6   balcony       12751 non-null  int64
#  7   price         12751 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 896.6+ KB

# %%
# Define a function to calculate IQR outliers
def detect_iqr_outliers(column):
    q1 = column.quantile(0.25)
    q3 = column.quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    return (column < lower_bound) | (column > upper_bound)


# Select only numerical columns
#numerical_cols = df2.select_dtypes(include=['number']).columns



# Apply the function to numerical columns
outliers_iqr = df2[[ 'size', 'total_sqft', 'bath',
       'balcony', 'price']].apply(detect_iqr_outliers)

# View outliers
print("Outliers detected using IQR:")
print(outliers_iqr.sum())  # Count of outliers per column
# Out:
# Outliers detected using IQR:
# size           839
# total_sqft    1164
# bath          1032
# balcony          0
# price         1214
# dtype: int64

# %%
# Filter out the rows after removing outliers
df2 = df2[~(outliers_iqr.any(axis=1))]
print("Data after removing outliers (IQR):")
print(df2)
# Out:
# Data after removing outliers (IQR):
#                   area_type   availability                  location  size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II     2
# 2            Built-up  Area  Ready To Move               Uttarahalli     3
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli     3
# 4      Super built-up  Area  Ready To Move                  Kothanur     2
# 5      Super built-up  Area  Ready To Move                Whitefield     2
# ...                     ...            ...                       ...   ...
# 13309  Super built-up  Area  Ready To Move              Yeshwanthpur     3
# 13310  Super built-up  Area  Ready To Move              Rachenahalli     2
# 13312  Super built-up  Area  Ready To Move                 Bellandur     2
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout     3
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar     2
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the plot size for all plots
plt.figure(figsize=(16, 12))

# Create a subplot grid for 4 plots (2 rows, 2 columns)
plt.subplot(2, 2, 1)
sns.boxplot(x='area_type', y='price', data=df2, palette="Set2")
plt.title('Price Distribution by Availability Status')
plt.xlabel('Availability Status')
plt.ylabel('Price')

plt.subplot(2, 2, 2)
sns.boxplot(x='area_type', y='total_sqft', data=df2, palette="Set2")
plt.title('Total Sqft Distribution by Availability Status')
plt.xlabel('Availability Status')
plt.ylabel('Total Sqft')

plt.subplot(2, 2, 3)
sns.boxplot(x='area_type', y='bath', data=df2, palette="Set2")
plt.title('Bath Distribution by Availability Status')
plt.xlabel('Availability Status')
plt.ylabel('Number of Bathrooms')

plt.subplot(2, 2, 4)
sns.boxplot(x='area_type', y='balcony', data=df2, palette="Set2")
plt.title('Balcony Distribution by Availability Status')
plt.xlabel('Availability Status')
plt.ylabel('Number of Balconies')

# Adjust the layout to ensure the plots fit nicely
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-150-33e1f5c742d7>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='area_type', y='price', data=df2, palette="Set2")
# <ipython-input-150-33e1f5c742d7>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='area_type', y='total_sqft', data=df2, palette="Set2")
# <ipython-input-150-33e1f5c742d7>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='area_type', y='bath', data=df2, palette="Set2")
# <ipython-input-150-33e1f5c742d7>:27: FutureWarning:
#
# ...

# %%
import numpy as np
from scipy.stats import zscore


# Compute Z-scores
z_scores = df2[[ 'size', 'total_sqft', 'bath',
       'balcony']].apply(zscore)

# Define threshold
threshold = 3

# Identify outliers
outliers_z = (z_scores.abs() > threshold)

# View outliers
print("Outliers detected using Z-Score:")
print(outliers_z.sum())  # Count of outliers per column
# Out:
# Outliers detected using Z-Score:
# size           0
# total_sqft    60
# bath           0
# balcony        0
# dtype: int64

# %%
print(df.shape)
print(df1.shape)
print(df2.shape)
# Out:
# (13320, 9)
# (12751, 8)
# (10573, 8)

# %% [markdown]
# # 5. **`FEATURE ENGINEERING`**

# %%
df3 = df2.copy()
df3
# Out:
#                   area_type   availability                  location  size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II     2
# 2            Built-up  Area  Ready To Move               Uttarahalli     3
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli     3
# 4      Super built-up  Area  Ready To Move                  Kothanur     2
# 5      Super built-up  Area  Ready To Move                Whitefield     2
# ...                     ...            ...                       ...   ...
# 13309  Super built-up  Area  Ready To Move              Yeshwanthpur     3
# 13310  Super built-up  Area  Ready To Move              Rachenahalli     2
# 13312  Super built-up  Area  Ready To Move                 Bellandur     2
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout     3
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar     2
#
#        total_sqft  bath  balcony   price
# ...

# %%
df3['availability'].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-Feb', '18-Nov', '18-May', '20-Dec',
#        '17-Oct', '21-Dec', '19-Sep', '20-Sep', '18-Mar', '18-Apr',
#        '20-Aug', '19-Mar', '17-Sep', '18-Dec', '17-Aug', '19-Apr',
#        '18-Jun', '22-Dec', '22-Jan', '18-Aug', '19-Jan', '17-Jul',
#        '18-Jul', '21-Jun', '19-Aug', '18-Sep', '17-Jun', '18-Oct',
#        '21-May', '18-Jan', '20-Mar', '17-Dec', '16-Mar', '19-Jun',
#        '22-Jun', '17-May', '19-Jul', '21-Feb', 'Immediate Possession',
#        '19-May', '20-Oct', '20-Jun', '19-Feb', '21-Oct', '21-Jan',
#        '17-Mar', '17-Nov', '17-Apr', '19-Oct', '21-Jul', '21-Nov',
#        '21-Mar', '16-Dec', '22-Mar', '20-Jan', '21-Sep', '21-Aug',
#        '22-May', '14-Nov', '19-Nov', '15-Nov', '16-Jul', '15-Jun',
#        '20-May', '20-Nov', '20-Jul', '16-Sep', '15-Oct', '20-Feb',
#        '15-Dec', '16-Oct', '22-Nov', '15-Aug', '17-Jan', '16-Nov',
#        '20-Apr', '16-Jan', '17-Feb', '14-Jul'], dtype=object)

# %%
df3['availability_status'] = np.where(df3['availability'] == 'Ready To Move', 'Immediatly available', 'Available Later')
df3.drop(columns=['availability'], inplace=True)

# %%
df3['availability_status'].value_counts()
# Out:
# availability_status
# Immediatly available    8250
# Available Later         2323
# Name: count, dtype: int64

# %%
df3
# Out:
#                   area_type                  location  size  total_sqft  bath  \
# 0      Super built-up  Area  Electronic City Phase II     2      1056.0     2
# 2            Built-up  Area               Uttarahalli     3      1440.0     2
# 3      Super built-up  Area        Lingadheeranahalli     3      1521.0     3
# 4      Super built-up  Area                  Kothanur     2      1200.0     2
# 5      Super built-up  Area                Whitefield     2      1170.0     2
# ...                     ...                       ...   ...         ...   ...
# 13309  Super built-up  Area              Yeshwanthpur     3      1675.0     3
# 13310  Super built-up  Area              Rachenahalli     2      1050.0     2
# 13312  Super built-up  Area                 Bellandur     2      1262.0     2
# 13314  Super built-up  Area         Green Glen Layout     3      1715.0     3
# 13317        Built-up  Area     Raja Rajeshwari Nagar     2      1141.0     2
#
# ...

# %%
sns.barplot(x='availability_status', y='price', data=df3)
# Out:
# <Axes: xlabel='availability_status', ylabel='price'>

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10573 entries, 0 to 13317
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   area_type            10573 non-null  object
#  1   location             10573 non-null  object
#  2   size                 10573 non-null  int64
#  3   total_sqft           10573 non-null  float64
#  4   bath                 10573 non-null  int64
#  5   balcony              10573 non-null  int64
#  6   price                10573 non-null  float64
#  7   availability_status  10573 non-null  object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 743.4+ KB

# %% [markdown]
# # **`FEATURE SLELECTION`**

# %%
skewness = df3[['size', 'total_sqft', 'bath', 'balcony','price']].skew()
print(skewness)
# Out:
# size          0.127078
# total_sqft    0.488794
# bath          0.572510
# balcony       0.101757
# price         1.311693
# dtype: float64

# %%
skewness = df1[['size', 'total_sqft', 'bath', 'balcony','price']].skew()
print(skewness)
# Out:
# size           4.798165
# total_sqft    15.074989
# bath           4.210408
# balcony        0.093945
# price          7.945099
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in ['size', 'total_sqft', 'bath', 'balcony', 'price']:
    sns.histplot(df3[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
# Square root transformation for 'price'
df3['price_sqrt'] = np.sqrt(df3['price'])
df3['price_sqrt'].skew()
# Display the results
print(df3[[ 'price_sqrt']])
# df3.drop(columns=['price'], inplace=True)
# Out:
#        price_sqrt
# 0        6.250600
# 2        7.874008
# 3        9.746794
# 4        7.141428
# 5        6.164414
# ...           ...
# 13309    9.598437
# 13310    7.260165
# 13312    6.855655
# 13314   10.583005
# 13317    7.745967
#
# [10573 rows x 1 columns]

# %%
df3['log_price']=np.log1p(df3['price'])
df3['log_price'].skew()
# Out:
# -0.031341607666230696

# %%
df3['price_sqrt'].skew()
# Out:
# 0.6717077143086152

# %%
df3.drop(columns=['price','price_sqrt'], inplace=True)

# %% [markdown]
# # **`ENCODING`**

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10573 entries, 0 to 13317
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   area_type            10573 non-null  object
#  1   location             10573 non-null  object
#  2   size                 10573 non-null  int64
#  3   total_sqft           10573 non-null  float64
#  4   bath                 10573 non-null  int64
#  5   balcony              10573 non-null  int64
#  6   availability_status  10573 non-null  object
#  7   log_price            10573 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 743.4+ KB

# %%
df3.nunique()
# Out:
# area_type                 4
# location               1102
# size                      4
# total_sqft             1445
# bath                      4
# balcony                   4
# availability_status       2
# log_price              1701
# dtype: int64

# %%
df3['location'].unique()
# Out:
# array(['Electronic City Phase II', 'Uttarahalli', 'Lingadheeranahalli',
#        ..., 'Tilak Nagar',
#        '12th cross srinivas nagar banshankari 3rd stage', 'Abshot Layout'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df3['location'] = le.fit_transform(df3['location'])

df3['location'].dtype
# Out:
# dtype('int64')

# %%
df3['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Built-up  Area', 'Plot  Area',
#        'Carpet  Area'], dtype=object)

# %%
df3['area_type']=df3['area_type'].map({'Carpet  Area': 0, 'Plot  Area': 1,'Built-up  Area':2,'Super built-up  Area':3})
df3
# Out:
#        area_type  location  size  total_sqft  bath  balcony  \
# 0              3       342     2      1056.0     2        1
# 2              2       997     3      1440.0     2        3
# 3              3       639     3      1521.0     3        1
# 4              3       605     2      1200.0     2        1
# 5              3      1058     2      1170.0     2        1
# ...          ...       ...   ...         ...   ...      ...
# 13309          3      1071     3      1675.0     3        1
# 13310          3       808     2      1050.0     2        2
# 13312          3       181     2      1262.0     2        2
# 13314          3       390     3      1715.0     3        3
# 13317          2       815     2      1141.0     2        1
#
#         availability_status  log_price
# 0           Available Later   3.690628
# 2      Immediatly available   4.143135
# 3      Immediatly available   4.564348
# 4      Immediatly available   3.951244
# 5      Immediatly available   3.663562
# ...

# %%
df3['availability_status'].unique()
# Out:
# array(['Available Later', 'Immediatly available'], dtype=object)

# %%
one_hot_encoded = pd.get_dummies(df3['availability_status'], prefix='onehot', dtype=int)

df3 = pd.concat([df3, one_hot_encoded], axis=1)
df3
# Out:
#        area_type  location  size  total_sqft  bath  balcony  \
# 0              3       342     2      1056.0     2        1
# 2              2       997     3      1440.0     2        3
# 3              3       639     3      1521.0     3        1
# 4              3       605     2      1200.0     2        1
# 5              3      1058     2      1170.0     2        1
# ...          ...       ...   ...         ...   ...      ...
# 13309          3      1071     3      1675.0     3        1
# 13310          3       808     2      1050.0     2        2
# 13312          3       181     2      1262.0     2        2
# 13314          3       390     3      1715.0     3        3
# 13317          2       815     2      1141.0     2        1
#
#         availability_status  log_price  onehot_Available Later  \
# 0           Available Later   3.690628                       1
# 2      Immediatly available   4.143135                       0
# ...

# %%
df3.drop(columns=['availability_status'], inplace=True)

# %%
df3
# Out:
#        area_type  location  size  total_sqft  bath  balcony  log_price  \
# 0              3       342     2      1056.0     2        1   3.690628
# 2              2       997     3      1440.0     2        3   4.143135
# 3              3       639     3      1521.0     3        1   4.564348
# 4              3       605     2      1200.0     2        1   3.951244
# 5              3      1058     2      1170.0     2        1   3.663562
# ...          ...       ...   ...         ...   ...      ...        ...
# 13309          3      1071     3      1675.0     3        1   4.533996
# 13310          3       808     2      1050.0     2        2   3.983599
# 13312          3       181     2      1262.0     2        2   3.871201
# 13314          3       390     3      1715.0     3        3   4.727388
# 13317          2       815     2      1141.0     2        1   4.110874
#
#        onehot_Available Later  onehot_Immediatly available
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.heatmap(df3.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # `DATA SCAILING`

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10573 entries, 0 to 13317
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   area_type                    10573 non-null  int64
#  1   location                     10573 non-null  int64
#  2   size                         10573 non-null  int64
#  3   total_sqft                   10573 non-null  float64
#  4   bath                         10573 non-null  int64
#  5   balcony                      10573 non-null  int64
#  6   log_price                    10573 non-null  float64
#  7   onehot_Available Later       10573 non-null  int64
#  8   onehot_Immediatly available  10573 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 826.0 KB

# %%
df3.columns
# Out:
# Index(['area_type', 'location', 'size', 'total_sqft', 'bath', 'balcony',
#        'log_price', 'onehot_Available Later', 'onehot_Immediatly available'],
#       dtype='object')

# %% [markdown]
# ## `MINMAXSCALER`

# %%
from sklearn.preprocessing import MinMaxScaler


# MinMax Scaling
minmax_scaler = MinMaxScaler()

df_minmax_scaled = minmax_scaler.fit_transform(df3)

# %%
df_minmax_scaled
# Out:
# array([[1.        , 0.3106267 , 0.33333333, ..., 0.46018936, 1.        ,
#         0.        ],
#        [0.66666667, 0.90554042, 0.66666667, ..., 0.59962846, 0.        ,
#         1.        ],
#        [1.        , 0.58038147, 0.66666667, ..., 0.72942457, 0.        ,
#         1.        ],
#        ...,
#        [1.        , 0.164396  , 0.33333333, ..., 0.51583261, 0.        ,
#         1.        ],
#        [1.        , 0.35422343, 0.66666667, ..., 0.77966492, 0.        ,
#         1.        ],
#        [0.66666667, 0.74023615, 0.33333333, ..., 0.58968733, 0.        ,
#         1.        ]])

# %%
df_minmax_scaled = pd.DataFrame(df_minmax_scaled, columns=df3.columns)
df_minmax_scaled
# Out:
#        area_type  location      size  total_sqft      bath   balcony  \
# 0       1.000000  0.310627  0.333333    0.347564  0.333333  0.333333
# 1       0.666667  0.905540  0.666667    0.513152  0.333333  1.000000
# 2       1.000000  0.580381  0.666667    0.548081  0.666667  0.333333
# 3       1.000000  0.549500  0.333333    0.409659  0.333333  0.333333
# 4       1.000000  0.960945  0.333333    0.396723  0.333333  0.333333
# ...          ...       ...       ...         ...       ...       ...
# 10568   1.000000  0.972752  0.666667    0.614489  0.666667  0.333333
# 10569   1.000000  0.733878  0.333333    0.344976  0.333333  0.666667
# 10570   1.000000  0.164396  0.333333    0.436395  0.333333  0.666667
# 10571   1.000000  0.354223  0.666667    0.631738  0.666667  1.000000
# 10572   0.666667  0.740236  0.333333    0.384217  0.333333  0.333333
#
#        log_price  onehot_Available Later  onehot_Immediatly available
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots
plt.figure(figsize=(12, 10))

# Original and scaled data histograms for each feature
plt.subplot(5, 2, 1)
sns.histplot(df3['size'], kde=True)
plt.title('Original: size')

plt.subplot(5, 2, 2)
sns.histplot(df_minmax_scaled['size'], kde=True)
plt.title('Scaled: size')

plt.subplot(5, 2, 3)
sns.histplot(df3['total_sqft'], kde=True)
plt.title('Original: total_sqft')

plt.subplot(5, 2, 4)
sns.histplot(df_minmax_scaled['total_sqft'], kde=True)
plt.title('Scaled: total_sqft')

plt.subplot(5, 2, 5)
sns.histplot(df3['bath'], kde=True)
plt.title('Original: bath')

plt.subplot(5, 2, 6)
sns.histplot(df_minmax_scaled['bath'], kde=True)
plt.title('Scaled: bath')

plt.subplot(5, 2, 7)
sns.histplot(df3['balcony'], kde=True)
plt.title('Original: balcony')

plt.subplot(5, 2, 8)
sns.histplot(df_minmax_scaled['balcony'], kde=True)
plt.title('Scaled: balcony')

plt.subplot(5, 2, 9)
sns.histplot(df3['log_price'], kde=True)
plt.title('Original: price_log')

plt.subplot(5, 2, 10)
sns.histplot(df_minmax_scaled['log_price'], kde=True)
plt.title('Scaled: log_price')


plt.tight_layout()
plt.show()

# %% [markdown]
# ## `STANDARD SCALING`

# %%
from sklearn.preprocessing import StandardScaler


# Standardization
standard_scaler = StandardScaler()

df_standardized = standard_scaler.fit_transform(df3)

# %%
df_standardized = pd.DataFrame(df_standardized, columns=df3.columns)
df_standardized
# Out:
#        area_type  location      size  total_sqft      bath   balcony  \
# 0       0.571127 -0.698541 -0.648611   -0.624819 -0.443415 -0.683664
# 1      -0.893114  1.397581  0.823644    0.374750 -0.443415  1.868729
# 2       0.571127  0.251915  0.823644    0.585597  1.049176 -0.683664
# 3       0.571127  0.143108 -0.648611   -0.249981 -0.443415 -0.683664
# 4       0.571127  1.592793 -0.648611   -0.328072 -0.443415 -0.683664
# ...          ...       ...       ...         ...       ...       ...
# 10568   0.571127  1.634395  0.823644    0.986466  1.049176 -0.683664
# 10569   0.571127  0.792746 -0.648611   -0.640438 -0.443415  0.592533
# 10570   0.571127 -1.213771 -0.648611   -0.088592 -0.443415  0.592533
# 10571   0.571127 -0.544932  0.823644    1.090588  1.049176  1.868729
# 10572  -0.893114  0.815147 -0.648611   -0.403561 -0.443415 -0.683664
#
#        log_price  onehot_Available Later  onehot_Immediatly available
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots
plt.figure(figsize=(12, 10))

# Original and standardized data histograms for each feature
plt.subplot(5, 2, 1)
sns.histplot(df3['size'], kde=True)
plt.title('Original: size')

plt.subplot(5, 2, 2)
sns.histplot(df_standardized['size'], kde=True)
plt.title('Standardized: size')

plt.subplot(5, 2, 3)
sns.histplot(df3['total_sqft'], kde=True)
plt.title('Original: total_sqft')

plt.subplot(5, 2, 4)
sns.histplot(df_standardized['total_sqft'], kde=True)
plt.title('Standardized: total_sqft')

plt.subplot(5, 2, 5)
sns.histplot(df3['bath'], kde=True)
plt.title('Original: bath')

plt.subplot(5, 2, 6)
sns.histplot(df_standardized['bath'], kde=True)
plt.title('Standardized: bath')

plt.subplot(5, 2, 7)
sns.histplot(df3['balcony'], kde=True)
plt.title('Original: balcony')

plt.subplot(5, 2, 8)
sns.histplot(df_standardized['balcony'], kde=True)
plt.title('Standardized: balcony')


plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.heatmap(df_standardized.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
x=df_standardized.drop(columns=['log_price'])
y=df_standardized['log_price']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)

from sklearn.metrics import r2_score, mean_squared_error

# Validation predictions
y_pred = model.predict(x_test)  # Use validation set
r2_val = r2_score(y_test, y_pred)
mse_val = mean_squared_error(y_test, y_pred)

print("R² Score (Validation):", r2_val)
print("MSE (Validation):", mse_val)
# Out:
# R² Score (Validation): 0.5569679546066593
# MSE (Validation): 0.43485503154389954

# %% [markdown]
# # `DIMENSIONALITY REDUCTION`

# %% [markdown]
# ## PCA

# %%
x=df_standardized.drop(columns=['log_price'])
y=df_standardized['log_price']

# %%
x.head()
# Out:
#    area_type  location      size  total_sqft      bath   balcony  \
# 0   0.571127 -0.698541 -0.648611   -0.624819 -0.443415 -0.683664
# 1  -0.893114  1.397581  0.823644    0.374750 -0.443415  1.868729
# 2   0.571127  0.251915  0.823644    0.585597  1.049176 -0.683664
# 3   0.571127  0.143108 -0.648611   -0.249981 -0.443415 -0.683664
# 4   0.571127  1.592793 -0.648611   -0.328072 -0.443415 -0.683664
#
#    onehot_Available Later  onehot_Immediatly available
# 0                1.884527                    -1.884527
# 1               -0.530637                     0.530637
# 2               -0.530637                     0.530637
# 3               -0.530637                     0.530637
# 4               -0.530637                     0.530637

# %%
y.head()
# Out:
# 0   -1.029230
# 1   -0.120296
# 2    0.725781
# 3   -0.505740
# 4   -1.083597
# Name: log_price, dtype: float64

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
x_pca=pca.fit_transform(x)

# %%
x_pca
# Out:
# array([[-1.8698817 , -2.29265032],
#        [ 1.22863378,  0.68659812],
#        [ 1.26107535,  0.21911502],
#        ...,
#        [-0.29997578,  0.8911184 ],
#        [ 2.27709223,  0.19588647],
#        [-0.72784729,  1.02024685]])

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_pca, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score, mean_squared_error


# Validation predictions
y_pred = model.predict(x_test)  # Use validation set
r2_val = r2_score(y_test, y_pred)
mse_val = mean_squared_error(y_test, y_pred)


print("R² Score (Validation):", r2_val)
print("MSE (Validation):", mse_val)
# Out:
# R² Score (Validation): 0.4751471332108259
# MSE (Validation): 0.5151656913234725

# %% [markdown]
# ## `EVALUATION MATRICS IN REGRESSION`

# %%
# MAE (Mean Absolute Error)

from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
print('MAE:',mae)
# Out:
# MAE: 0.5670041140958089

# %%
# MSE (Mean Squared Error)

from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print('MSE: ',mse)
# Out:
# MSE:  0.5151656913234725

# %%
# RMSE (Root Mean Squared Error)
rmse = np.sqrt(mse)
print('RMSE: ',rmse)
# Out:
# RMSE:  0.7177504380517454

# %%
# R² Score (R-squared)

from sklearn.metrics import  r2_score

r2 = r2_score(y_test, y_pred)
print('R² Score: ',r2)
# Out:
# R² Score:  0.4751471332108259
